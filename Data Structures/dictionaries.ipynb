# %%
## Creating Dictionary
empty_dict = {}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
empty_dict = dict()
print(empty_dict)
# Out:
# {}

# %%
student = {
    "name": "Alice",
    "age": 20,
    "major": "Computer Science",
    "grades": 24
    }
print(student)
# Out:
# {'name': 'Alice', 'age': 20, 'major': 'Computer Science', 'grades': 24}

# %%
# Error since keys must be unique, the second "name" key will overwrite the first one
student_test = {
    "name": "Alice",
    "age": 20,
    "major": "Computer Science",
    "name": 24
    }
print(student_test)
# Out:
# {'name': 24, 'age': 20, 'major': 'Computer Science'}

# %%
print(student["name"])  # Accessing value by key
# Out:
# Alice

# %%
print(student.get("age"))  # Using get method to access value by key
# Out:
# 20

# %%
## Modifying Dictionary
student["age"] = 21  # Modifying existing key
print(student)

# Adding new key-value pair
student["graduation_year"] = 2024
print(student)

# Deleting a key-value pair
del student["grades"]
print(student)
# Out:
# {'name': 'Alice', 'age': 21, 'major': 'Computer Science', 'grades': 24, 'graduation_year': 2024}
# {'name': 'Alice', 'age': 21, 'major': 'Computer Science', 'grades': 24, 'graduation_year': 2024}
# {'name': 'Alice', 'age': 21, 'major': 'Computer Science', 'graduation_year': 2024}

# %%
# dictionary methods

keys = student.keys()
print(keys)
values = student.values()
print(values)


items = student.items()
print(items)
# Out:
# dict_keys(['name', 'age', 'major', 'graduation_year'])
# dict_values(['Alice', 21, 'Computer Science', 2024])
# dict_items([('name', 'Alice'), ('age', 21), ('major', 'Computer Science'), ('graduation_year', 2024)])

# %%
# shallow copy of dictionary
student_copy = student.copy()
print(student)
print(student_copy)
# Out:
# {'name': 'Alice', 'age': 21, 'major': 'Computer Science', 'graduation_year': 2024}
# {'name': 'Alice', 'age': 21, 'major': 'Computer Science', 'graduation_year': 2024}

# %%
student["name"]= "Alice"
print(student)
print(student_copy)
# Out:
# {'name': 'Alice', 'age': 21, 'major': 'Computer Science', 'graduation_year': 2024}
# {'name': 'Alice', 'age': 21, 'major': 'Computer Science', 'graduation_year': 2024}

# %%
student_copy1 = student.copy() #shallow copy
print(student_copy1)
print(student)
# Out:
# {'name': 'Alice', 'age': 21, 'major': 'Computer Science', 'graduation_year': 2024}
# {'name': 'Alice', 'age': 21, 'major': 'Computer Science', 'graduation_year': 2024}

# %%
student["name"] = "Bob"
print(student_copy1)
print(student)
# Out:
# {'name': 'Alice', 'age': 21, 'major': 'Computer Science', 'graduation_year': 2024}
# {'name': 'Bob', 'age': 21, 'major': 'Computer Science', 'graduation_year': 2024}

# %%
# I terating through dictionary
# you can use loops to itraing over dictionary keys, values, or key-value 

# Iterating over keys

for keys in student.keys():
    print( keys)
# Out:
# name
# age
# major
# graduation_year

# %%
# Iterating over values
for values in student.values():
    print( values)
# Out:
# Bob
# 21
# Computer Science
# 2024

# %%
# Itraite over key-value pairs
for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# name: Bob
# age: 21
# major: Computer Science
# graduation_year: 2024

# %%
# nested dictionaries

students = {
    "student1": {
        "name": "Alice",
        "age": 20,
        "major": "Computer Science"
    },
    "student2": {
        "name": "Bob",
        "age": 22,
        "major": "Mathematics"
    }
}

print(students)
# Out:
# {'student1': {'name': 'Alice', 'age': 20, 'major': 'Computer Science'}, 'student2': {'name': 'Bob', 'age': 22, 'major': 'Mathematics'}}

# %%
## Accessing nested dictionary values
print(students["student1"]["name"])  # Output: Alice
print(students["student2"]["major"])  # Output: Mathematics
# Out:
# Alice
# Mathematics

# %%
for student_id, student_info in students.items():
    print(f"{student_id}:")
    for key, value in student_info.items():
        print(f"  {key}: {value}")
# Out:
# student1:
#   name: Alice
#   age: 20
#   major: Computer Science
# student2:
#   name: Bob
#   age: 22
#   major: Mathematics

# %%
## Dictionary comprehension
squared_numbers = {x: x**2 for x in range(1, 6)}
print(squared_numbers)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
# conditions comprehension
even_squares = {x: x**2 for x in range(1, 11) if x % 2 == 0}
print(even_squares)
# Out:
# {2: 4, 4: 16, 6: 36, 8: 64, 10: 100}

# %%
#example
nunbers = [1,1,1, 2,2,2, 3,3,3, 4,4,4, 5,5,5]
frequency = {}

for number in nunbers:
    if number in frequency:
        frequency[number] += 1
    else:
        frequency[number] = 1
print(frequency)
# Out:
# {1: 3, 2: 3, 3: 3, 4: 3, 5: 3}

# %%
#merge two dictionaries
dict1 = {"a": 1, "b": 2, "d": 5}
dict2 = {"b": 3, "c": 4}
merged_dict = {**dict1, **dict2}
print(merged_dict)
# Out:
# {'a': 1, 'b': 3, 'd': 5, 'c': 4}
