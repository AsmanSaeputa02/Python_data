# %%
def equare(n):
    for i in range(10):
        yield i ** 2

# %%
equare(0)
# Out:
# <generator object equare at 0x000001FA8234A400>

# %%
for i in equare(0):
     print(i)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
## practical wit a large dataset
def read_large_file(file_path):
    with open(file_path,'r') as file :
        for line in file:
            yield line

# %%
file_path = 'large_file.txt'
for line in read_large_file(file_path):
    print(line.strip())
# Out:
# id,timestamp,user_id,text,label,feature1,feature2
# 1,2026-01-01T00:00:00Z,u1001,"User reports slow performance on login.",bug,0.72,12
# 2,2026-01-01T00:01:23Z,u1002,"Loved the new update, great UX!",praise,0.15,7
# 3,2026-01-01T00:02:45Z,u1003,"Error 503 when accessing /api/data.",bug,0.88,20
# 4,2026-01-01T00:03:10Z,u1004,"Would like dark mode option.",feature_request,0.30,5
# 5,2026-01-01T00:05:00Z,u1005,"Payment failed with card ending 1234.",bug,0.80,18
# 6,2026-01-01T00:06:17Z,u1006,"How do I reset my password?",question,0.40,9
# 7,2026-01-01T00:07:50Z,u1007,"App crashes on startup (Android 11).",bug,0.95,25
# 8,2026-01-01T00:09:02Z,u1008,"Feature X is very useful, thanks.",praise,0.10,4
# 9,2026-01-01T00:10:30Z,u1009,"Request: export data as CSV.",feature_request,0.25,6
# 10,2026-01-01T00:11:55Z,u1010,"Subscription renewal not processed.",bug,0.67,14
# 11,2026-01-01T00:13:12Z,u1011,"Is two-factor auth supported?",question,0.35,8
# ...
