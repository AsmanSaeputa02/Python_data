# %%
### create a tuple
empty_tuple = ()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst = list()
print(type(lst))
tpl = tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
numbers = tuple([1, 2, 3, 4, 5,5])
numbers
# Out:
# (1, 2, 3, 4, 5, 5)

# %%
list((1, 2, 3, 4, 5,5))
# Out:
# [1, 2, 3, 4, 5, 5]

# %%
mixed_tuple = (1, 'hello', 3.14, [1, 2, 3], (4, 5))
print(mixed_tuple)
# Out:
# (1, 'hello', 3.14, [1, 2, 3], (4, 5))

# %%
# Accessing tuple elements
numbers
# Out:
# (1, 2, 3, 4, 5, 5)

# %%
numbers[0]
# Out:
# 1

# %%
numbers  + mixed_tuple
# Out:
# (1, 2, 3, 4, 5, 5, 1, 'hello', 3.14, [1, 2, 3], (4, 5))

# %%
numbers*3
# Out:
# (1, 2, 3, 4, 5, 5, 1, 2, 3, 4, 5, 5, 1, 2, 3, 4, 5, 5)

# %%
mixed_tuple *3
# Out:
# (1,
#  'hello',
#  3.14,
#  [1, 2, 3],
#  (4, 5),
#  1,
#  'hello',
#  3.14,
#  [1, 2, 3],
#  (4, 5),
#  1,
#  'hello',
#  3.14,
#  [1, 2, 3],
#  (4, 5))
